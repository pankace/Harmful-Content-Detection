# %% [markdown]
# # Racist Content Detection Experiement (Final Model)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import nomic

from nomic import embed
from collections import Counter

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('./data/tweets.csv', usecols=['Cleaned tweet', 'Tag'])
df.columns = ['text', 'label']
df_sample = df.sample(frac=1, random_state=42).reset_index(drop=True)
df_sample.head()
# Out:
#                                                 text  label
# 0  People have the right to be wherever we want a...      0
# 1  And meanwhile, in the Madrid neighborhood of E...      1
# 2  I hear my mom say “fucking black man” “no soul...      0
# 3  You are wrong, bastard, you are just another i...      1
# 4  It's just that you see a black man with luxuri...      0

# %% [markdown]
# ### Data Preprocessing

# %%
def remove_non_ascii(text):
    return re.sub(r'[^\x00-\x7F]+', '', text)

df_sample['text'] = df_sample['text'].apply(remove_non_ascii)
df_sample.head()
# Out:
#                                                 text  label
# 0  People have the right to be wherever we want a...      0
# 1  And meanwhile, in the Madrid neighborhood of E...      1
# 2  I hear my mom say fucking black man no soul sk...      0
# 3  You are wrong, bastard, you are just another i...      1
# 4  It's just that you see a black man with luxuri...      0

# %%
missing_values = df_sample.isnull().sum()
label_dist = df_sample['label'].value_counts(normalize=True)

print("Missing Values:\n", missing_values)
print("Label Distribution:\n", label_dist)
# Out:
# Missing Values:
#  text     0
# label    0
# dtype: int64
# Label Distribution:
#  label
# 0    0.5135
# 1    0.4865
# Name: proportion, dtype: float64

# %% [markdown]
# ### Model

# %%
output = embed.text(
    texts=df_sample['text'].tolist(),
    model='nomic-embed-text-v1',
)

print(output['usage'])

embeddings = np.array(output['embeddings'])

print(embeddings.shape)
# Out:
# {'prompt_tokens': 75934, 'total_tokens': 75934}
# (2000, 768)

# %%
X_train, X_test, y_train, y_test = train_test_split(embeddings,  df_sample['label'], test_size=0.2, random_state=42)

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)
y_pred = lr_model.predict(X_test)

print("Accuracy:", lr_model.score(X_test, y_test))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       208
#            1       0.82      0.80      0.81       192
#
#     accuracy                           0.82       400
#    macro avg       0.82      0.82      0.82       400
# weighted avg       0.82      0.82      0.82       400

# %%
param_grid = {
    'n_estimators': [200, 400, 600], 
    'max_depth': [None, 10, 20, 30],  
    'min_samples_split': [2, 5, 10, 15],  
    'min_samples_leaf': [1, 2, 4]
}

rf_model = RandomForestClassifier(random_state=42)

grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

print("Best Params:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   9.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  19.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  19.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  20.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  20.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  20.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  29.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  29.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  29.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  30.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  20.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   9.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  29.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  20.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  20.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  20.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  20.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  10.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  31.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  31.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  20.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  20.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  31.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  31.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  31.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  33.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  33.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  33.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  34.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  35.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  34.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  35.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  34.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  34.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  33.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  33.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  11.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  33.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  22.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  22.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  22.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  22.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  11.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  22.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  11.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  34.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  34.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  34.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  12.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  23.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  35.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  24.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  24.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  24.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  35.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  24.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  12.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  12.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  12.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  11.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  35.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  35.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  35.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  35.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  22.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  22.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  22.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  22.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  35.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  22.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  35.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  35.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  35.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  35.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  35.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  23.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  23.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  23.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  23.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  23.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  34.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  34.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  34.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  34.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  34.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  11.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  23.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  23.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  23.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  23.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  11.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  11.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  23.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  11.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  34.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  34.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  11.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  23.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  34.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  34.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  34.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  22.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  22.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  22.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  22.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  11.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  11.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  34.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  33.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  34.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  34.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  34.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  22.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  23.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  12.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  22.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  22.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  22.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  13.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  12.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  12.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  12.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  34.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  37.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  36.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  37.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  37.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  27.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  28.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  28.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  28.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  15.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  28.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  14.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  48.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  48.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  17.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  32.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  47.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  47.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  32.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  47.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  32.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  32.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  31.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  42.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  42.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  42.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  39.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  40.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  21.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  10.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  32.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  32.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  32.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  32.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  32.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  32.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  23.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  23.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  23.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  35.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  35.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  35.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  34.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  11.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  35.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  23.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  24.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  24.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  25.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  25.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  41.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  54.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  54.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  54.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  53.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  52.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  10.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  10.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  10.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  10.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.0min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  21.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  10.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  32.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  32.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  32.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  32.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  21.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  21.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  33.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  21.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  11.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  32.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  32.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  33.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  33.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time= 3.3min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 3.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 2.9min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 3.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 3.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 3.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time= 3.1min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 2.9min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 2.9min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time= 2.8min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time= 3.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time= 3.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time= 3.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time= 3.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   8.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time= 3.2min
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  17.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  17.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  17.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  17.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  17.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   8.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   8.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   8.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=   8.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  26.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  26.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  26.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  26.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  27.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  17.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  18.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  17.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  18.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  18.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  11.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  11.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  11.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  11.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  11.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  27.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  27.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  27.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  27.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  28.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  12.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  12.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  12.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  12.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  23.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  24.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  12.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  23.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  23.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=  23.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  34.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  22.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  35.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  34.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  34.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  35.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  22.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  22.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  22.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  22.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  11.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  34.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  34.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  35.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  34.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  35.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  11.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  23.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  23.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  23.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  24.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  24.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  11.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  11.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  11.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  11.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  35.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  35.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  10.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  34.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  34.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  35.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  22.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  11.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  33.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  33.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  33.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  33.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  10.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time=  33.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  21.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  22.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  11.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  12.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  12.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  12.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  35.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  35.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  36.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  36.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  36.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  26.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  26.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  26.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  26.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  26.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  13.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  14.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  14.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  42.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  42.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  42.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  14.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  42.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  29.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  29.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  42.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  29.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  29.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  29.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  13.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  13.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  13.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  14.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  43.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  43.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time=  43.5s
# ...
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  36.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time=  36.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  19.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  19.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  20.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  20.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  56.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  56.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  57.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  57.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=  58.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  19.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  39.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  39.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  39.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  39.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  40.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  20.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  20.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  20.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  20.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  24.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  46.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  46.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  47.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  47.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=400; total time=  48.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  25.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  25.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  25.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  25.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time= 1.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time= 1.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  20.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time= 1.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time= 1.2min
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=15, n_estimators=600; total time= 1.2min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  44.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  44.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  43.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  43.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  43.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  22.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time= 1.1min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  43.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  43.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  43.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  43.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  43.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  20.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  19.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  40.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  40.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  41.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  41.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  41.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  20.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  20.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  20.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=  20.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  19.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=600; total time= 1.0min
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  41.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  41.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  40.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  40.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=400; total time=  40.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  16.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  16.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  16.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  16.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  57.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  57.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  57.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  31.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  15.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  55.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  32.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  31.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=15, n_estimators=600; total time=  56.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  32.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  32.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  16.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  16.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  16.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  15.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  47.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  47.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  47.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  46.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=600; total time=  46.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  14.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  30.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  30.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  30.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  30.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=400; total time=  30.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  14.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  15.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  15.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  15.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  44.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  45.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  44.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  14.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  44.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=600; total time=  45.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  30.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  29.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  29.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  29.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  30.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  15.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  14.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  14.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time=  15.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  45.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  44.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  44.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  44.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=600; total time=  44.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  28.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  28.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  27.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  27.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=400; total time=  27.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  36.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  36.1s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  35.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  34.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=15, n_estimators=600; total time=  33.8s
# Best Params: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 600}
# Best Score: 0.7925000000000001

# %%
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.815
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       208
#            1       0.84      0.76      0.80       192
#
#     accuracy                           0.81       400
#    macro avg       0.82      0.81      0.81       400
# weighted avg       0.82      0.81      0.81       400

# %% [markdown]
# ### Examples

# %% [markdown]
# #### Racist Examples
# **Note**: [source of racist tweets](https://humanrights.gov.au/our-work/publications/examples-racist-material-internet)

# %%
test = """If we do not stand now and perform our god given duty to keep OUR country 
        clean of all the Blacks, Jews and Yellow scum from Asia, WE are just as bad as the enemy, 
        if not worse. We are trading our race for that of an inferior form of trash"""

test_embedding = embed.text(texts=[test], model='nomic-embed-text-v1')
test_embedding = np.array(test_embedding['embeddings'])
prediction = best_rf.predict(test_embedding)

if prediction[0] == 1:
    print("Racist")
else:
    print("Not racist")
# Out:
# Racist

# %%
test = """Arabs… have little or no knowledge of personal hygiene products 
        such as deodorant or even soap…nothing has ever turned my stomach like the 
        fetid stench of unwashed wogs!"""

test_embedding = embed.text(texts=[test], model='nomic-embed-text-v1')
test_embedding = np.array(test_embedding['embeddings'])
prediction = best_rf.predict(test_embedding)

if prediction[0] == 1:
    print("Racist")
else:
    print("Not racist")
# Out:
# Racist

# %%
test = """…it is a world run by the Zionist Jewish Influence and 
        Race Tainting Paedophiles that are only here to rape our heritage and 
        destroy the qualities that make us White People great…"""

test_embedding = embed.text(texts=[test], model='nomic-embed-text-v1')
test_embedding = np.array(test_embedding['embeddings'])
prediction = best_rf.predict(test_embedding)

if prediction[0] == 1:
    print("Racist")
else:
    print("Not racist")
# Out:
# Racist

# %% [markdown]
# #### Not Racist Examples

# %%
test = """Immigration policies should prioritize our own citizens' needs first. 
        Why should taxpayers bear the burden of supporting fucking migrants when there 
        are pressing issues at home?"""

test_embedding = embed.text(texts=[test], model='nomic-embed-text-v1')
test_embedding = np.array(test_embedding['embeddings'])
prediction = best_rf.predict(test_embedding)

if prediction[0] == 1:
    print("Racist")
else:
    print("Not racist")
# Out:
# Not racist

# %%
test = """The corrupt politician is not interested in knowing 
        that his broom is dirtier than what he is trying to sweep."""

test_embedding = embed.text(texts=[test], model='nomic-embed-text-v1')
test_embedding = np.array(test_embedding['embeddings'])
prediction = best_rf.predict(test_embedding)

if prediction[0] == 1:
    print("Racist")
else:
    print("Not racist")
# Out:
# Not racist
